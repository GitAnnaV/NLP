# %% [markdown]
# <a href="https://colab.research.google.com/github/GitAnnaV/NLP/blob/main/LAB_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Решение задач Классификация Кластеризация Генерация

# %% [markdown]
# ### Collect data

# %% [markdown]
# Установка и импорт необходимых библиотек

# %%
# !pip install pymorphy3
# Out:
# Collecting pymorphy3
#   Downloading pymorphy3-2.0.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Downloading pymorphy3-2.0.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.3 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 27.3 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.3 pymorphy3-dicts-ru-2.4.417150.4580142

# %%
import pandas as pd
import numpy as np
import pymorphy3
import nltk
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import SpectralClustering
from sklearn.metrics import silhouette_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# Загрузка данных

# %%
df = pd.read_csv('/content/movie.csv')

# %%
texts = df['overview']
categories = df['name']

# %% [markdown]
# Визуализация

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='name', data=df, order=categories.value_counts().index)
plt.title('Распределение категорий')
plt.xlabel('Категории')
plt.xticks(rotation=90)
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# ### Prepare data

# %% [markdown]
# Токенизация и лемматизация

# %%
morph = pymorphy3.MorphAnalyzer()

def preprocessing(text):
    # токенизация
    tokens = word_tokenize(text.lower())
    # лемматизация
    lemmatized_tokens = [
        morph.parse(token)[0].normal_form
        for token in tokens if token.isalpha()]

    return ' '.join(lemmatized_tokens)

# %%
preprocessed_texts = texts.apply(preprocessing)
print(preprocessed_texts)
# Out:
# 0       firemen brothers brian and stephen mccaffrey b...
# 1       factory worker doug quaid takes a virtual vaca...
# 2       milan italy santo russo a boy of calabrian ori...
# 3       zed is an american who travels to paris to mee...
# 4       a former marine confronts corruption in a smal...
#                               ...
# 2995    in the ruins of berlin a boy is left to his ow...
# 2996    a young man is afraid of asking for sex tips t...
# 2997    in this feature film based on the hit animated...
# 2998    an unsuspecting disenchanted man finds himself...
# 2999    alex an immigrant from ukraine comes to canada...
# Name: overview, Length: 3000, dtype: object

# %% [markdown]
# Векторизация через TFIDF

# %%
vectorizer = TfidfVectorizer(max_features=5000)
X = vectorizer.fit_transform(preprocessed_texts)

# %% [markdown]
# Кластеризация с помощью Spectral Clustering

# %%
# Масштабирование данных
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X.toarray())

# %%
spectral = SpectralClustering(
    n_clusters=19,
    affinity='nearest_neighbors',
    n_neighbors=10,
    random_state=42
)
labels = spectral.fit_predict(X_scaled)

# %% [markdown]
# Визуализация

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(
    x=X_pca[:, 0],
    y=X_pca[:, 1],
    hue=labels,
    palette='viridis',
    legend='full'
)
plt.title('Spectral Clustering (PCA projection)')
plt.show()

# %% [markdown]
# ### Сравнение результатов с реальной разметкой

# %%
if len(set(labels)) > 1:
    score = silhouette_score(X_scaled, labels)
    print(f"Silhouette Score: {score:.3f}")
else:
    print("Все точки в одном кластере!")

# Анализ результатов
df['cluster'] = labels
for cluster in sorted(df['cluster'].unique()):
    print(f"\n Кластер {cluster}:")
    print(df[df['cluster'] == cluster]['name'].value_counts().head(5))
# Out:
# Silhouette Score: -0.123
#
#  Кластер 0:
# name
# Romance      15
# Animation    14
# History      14
# Action       13
# Music        12
# Name: count, dtype: int64
#
#  Кластер 1:
# name
# Fantasy            61
# Comedy             55
# Drama              53
# Documentary        53
# Science Fiction    52
# Name: count, dtype: int64
#
#  Кластер 2:
# name
# Romance            1
# Science Fiction    1
# Western            1
# Name: count, dtype: int64
#
#  Кластер 3:
# name
# Science Fiction    21
# Documentary        16
# Drama              15
# Crime              15
# Thriller           14
# Name: count, dtype: int64
#
#  Кластер 4:
# name
# Drama              2
# Romance            1
# Western            1
# Science Fiction    1
# Name: count, dtype: int64
#
#  Кластер 5:
# name
# Horror       3
# Family       3
# History      3
# Crime        2
# Animation    2
# Name: count, dtype: int64
#
#  Кластер 6:
# name
# Music      17
# Comedy     16
# Fantasy    15
# Western    14
# Romance    14
# Name: count, dtype: int64
#
#  Кластер 7:
# name
# History            1
# Documentary        1
# Romance            1
# Science Fiction    1
# Fantasy            1
# Name: count, dtype: int64
#
#  Кластер 8:
# name
# Horror       5
# Romance      3
# Adventure    3
# History      2
# Fantasy      2
# Name: count, dtype: int64
#
#  Кластер 9:
# name
# Documentary    7
# TV Movie       6
# Family         6
# History        6
# Western        5
# Name: count, dtype: int64
#
#  Кластер 10:
# name
# Comedy       10
# Romance       6
# Adventure     6
# TV Movie      6
# War           5
# Name: count, dtype: int64
#
#  Кластер 11:
# name
# Action             5
# War                5
# Adventure          4
# Science Fiction    3
# Fantasy            3
# Name: count, dtype: int64
#
#  Кластер 12:
# name
# TV Movie           29
# Romance            28
# Science Fiction    27
# Documentary        25
# Horror             25
# Name: count, dtype: int64
#
#  Кластер 13:
# name
# Drama       11
# Comedy      10
# Thriller    10
# Crime       10
# Music       10
# Name: count, dtype: int64
#
#  Кластер 14:
# name
# Thriller       18
# Family         17
# Horror         16
# Documentary    16
# Mystery        14
# Name: count, dtype: int64
#
#  Кластер 15:
# name
# War          8
# Adventure    8
# Family       7
# History      7
# Mystery      6
# Name: count, dtype: int64
#
#  Кластер 16:
# name
# Drama     2
# Family    1
# Name: count, dtype: int64
#
#  Кластер 17:
# name
# Drama     1
# Family    1
# War       1
# Name: count, dtype: int64
#
#  Кластер 18:
# name
# Western            18
# Action             15
# Science Fiction    14
# Fantasy            13
# Crime              13
# Name: count, dtype: int64

# %% [markdown]
# ### Разделение на train, test и val выборки

# %%
train_data, temp_data = train_test_split(df, test_size=0.3, random_state=42)
val_data, test_data = train_test_split(temp_data, test_size=0.5, random_state=42)

print(train_data)
print(test_data)
print(val_data)
# Out:
#                 title                                           overview  \
# 611     Anna Karenina  In Imperial Russia, Anna, the wife of the offi...
# 530    50 First Dates  Henry is a player skilled at seducing women. B...
# 2787       The 'Burbs  When secretive new neighbors move in next door...
# 49    Stealing Beauty  Lucy Harmon, an American teenager is arriving ...
# 1883            Cyrus  With John's social life at a standstill and hi...
# ...               ...                                                ...
# 1638    Tale of Tales  The Queen of Selvascura risks everything to be...
# 1095    Inland Empire  An actress’s perception of reality becomes inc...
# 1130     Wolf Creek 2  Lured by the promise of an Australian holiday,...
# 1294          Ghosted  Salt-of-the-earth Cole falls head over heels f...
# 860    Apocalypse Now  At the height of the Vietnam war, Captain Benj...
#
#           name  cluster
# 611      Music       14
# 530   Thriller        6
# 2787    Family        0
# 49      Comedy       12
# 1883       NaN       14
# ...        ...      ...
# 1638     Music       18
# 1095  Thriller        1
# 1130    Action       13
# 1294    Comedy       12
# 860        War        6
#
# [2100 rows x 4 columns]
#                         title  \
# 1694            Standing Tall
# 1450  Ip Man: The Final Fight
# 1831            Transporter 2
# 676                      Alps
# 1298              The Verdict
# ...                       ...
# 1582                The Rider
# 1264               Open Grave
# 1429   Step Up 2: The Streets
# 1057                    50/50
# 381                 Submarine
#
#                                                overview       name  cluster
# 1694  The film tells the story of Malony and his edu...  Animation       18
# 1450  Ip Man reluctantly begins a series of challeng...     Family        1
# 1831  Professional driver, and former Special Forces...    Romance       12
# 676   A nurse, a paramedic, a gymnast and her coach ...     Comedy       12
# 1298  Frank Galvin is a down-on-his-luck lawyer and ...      Music       13
# ...                                                 ...        ...      ...
# 1582  Once a rising star of the rodeo circuit, and a...     Action       14
# 1264  A man awakes-- without memory -- in a pit full...     Family       14
# 1429  When rebellious street dancer Andie lands at t...        War       18
# 1057  Inspired by a true story, a comedy centered on...     Family       18
# 381   15-year-old deep-thinking Welsh schoolboy Oliv...    Romance        3
#
# [450 rows x 4 columns]
#                             title  \
# 581                     Rambo III
# 568                          Cujo
# 2477   Nothing Left to Do But Cry
# 445                     Cat's Eye
# 314                      Steamboy
# ...                           ...
# 1965                        Devil
# 1967                   Just Cause
# 2723  The Knight Before Christmas
# 1210            Gabriel's Inferno
# 685                          Hope
#
#                                                overview             name  \
# 581   Combat has taken its toll on Rambo, but he's f...        Adventure
# 568   A friendly St. Bernard named "Cujo" contracts ...           Comedy
# 2477  Two 20th-century friends accidentally stumble ...            Crime
# 445   Three short stories linked by a stray cat that...  Science Fiction
# 314   After receiving a package from his grandfather...      Documentary
# ...                                                 ...              ...
# 1965  A group of people are trapped in an elevator h...         Thriller
# 1967  A Harvard professor is lured back into the cou...  Science Fiction
# 2723  A medieval English knight is magically transpo...          Western
# 1210  An intriguing and sinful exploration of seduct...           Horror
# 685   After 8-year-old So-won narrowly survives a br...        Adventure
#
#       cluster
# 581        10
# 568         6
# 2477       18
# 445        15
# 314         1
# ...       ...
# 1965       18
# 1967        3
# 2723        6
# 1210       13
# 685         1
#
# [450 rows x 4 columns]
